# %%
import time
import threading
import logging
import pytest
import requests
from pydantic import BaseModel
import asyncio
import rustapi
import json

# Configure logging for pytest terminal output (use -s flag to view)
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[logging.StreamHandler()]
)
logger = logging.getLogger("RustAPI-PyTest")

HOST = "127.0.0.1"
PORT = 8000
BASE = f"http://{HOST}:{PORT}"

app = rustapi.Engine()

# %%
@app.get("/")
async def root():
    return {"message": "Hello, World!"}

# %%
app.run(host=HOST, port=PORT, reload=False)
# Out:
# 🚀 rustapi listening on http://127.0.0.1:8000
# [INFO] GET / - 200 (0ms)
# [INFO] GET /favicon.ico - 404 (0ms)
